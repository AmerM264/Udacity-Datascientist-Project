# %%
# %matplotlib inline
import json
import country_converter as coco
from datetime import datetime, timedelta
import requests
import pandas as pd
import geopandas as gpd
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
#Read survey data file
survey_df = pd.read_csv('/home/jovyan/demo/Stack_overflow/survey_results_public_2018.csv',low_memory=False,delimiter=',')

# %%
survey_df.head()
# Out:
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                              DevType  ...  \
# 0                               Full-stack developer  ...
# 1  Database administrator;DevOps specialist;Full-...  ...
# 2           Engineering manager;Full-stack developer  ...
# 3                               Full-stack developer  ...
# 4  Data or business analyst;Desktop or enterprise...  ...
#
#                      Exercise Gender         SexualOrientation  \
# 0        3 - 4 times per week   Male  Straight or heterosexual
# 1   Daily or almost every day   Male  Straight or heterosexual
# 2                         NaN    NaN                       NaN
# 3  I don't typically exercise   Male  Straight or heterosexual
# 4        3 - 4 times per week   Male  Straight or heterosexual
#
#                                     EducationParents  \
# 0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                                                NaN
# 3  Some college/university study without earning ...
# 4  Some college/university study without earning ...
#
#                   RaceEthnicity                Age Dependents  MilitaryUS  \
# 0   Black or of African descent  25 - 34 years old        Yes         NaN
# 1  White or of European descent  35 - 44 years old        Yes         NaN
# 2                           NaN                NaN        NaN         NaN
# 3  White or of European descent  35 - 44 years old         No          No
# 4  White or of European descent  18 - 24 years old        Yes         NaN
#
#                           SurveyTooLong     SurveyEasy
# 0  The survey was an appropriate length      Very easy
# 1  The survey was an appropriate length  Somewhat easy
# 2                                   NaN            NaN
# 3  The survey was an appropriate length  Somewhat easy
# 4  The survey was an appropriate length  Somewhat easy
#
# [5 rows x 129 columns]

# %%
#Data Understanding and Finding % of Missing Values
def missing_data_summary(survey_df):
    return pd.DataFrame({
                        'column_name'  : survey_df.columns,
                        'missing_rows' : list(survey_df.isna().sum()),
                        'missing_%'    : list((survey_df.isna().sum()/survey_df.shape[0])* 100)
    }
    )\
    .sort_values(by = 'missing_rows' , ascending = False)\
    .reset_index(drop = True)\
    .style\
    .set_caption(f'Total Rows: {survey_df.shape[0]}')\
    .background_gradient(cmap = 'viridis')

# %%
missing_data_summary(survey_df)
# Out:
# <style type="text/css">
# #T_eec6c_row0_col1, #T_eec6c_row0_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_eec6c_row1_col1, #T_eec6c_row1_col2 {
#   background-color: #bddf26;
#   color: #000000;
# }
# #T_eec6c_row2_col1, #T_eec6c_row2_col2 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_eec6c_row3_col1, #T_eec6c_row3_col2 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_eec6c_row4_col1, #T_eec6c_row4_col2 {
#   background-color: #34b679;
#   color: #f1f1f1;
# }
# #T_eec6c_row5_col1, #T_eec6c_row5_col2 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_eec6c_row6_col1, #T_eec6c_row6_col2, #T_eec6c_row7_col1, #T_eec6c_row7_col2, #T_eec6c_row8_col1, #T_eec6c_row8_col2, #T_eec6c_row9_col1, #T_eec6c_row9_col2, #T_eec6c_row10_col1, #T_eec6c_row10_col2, #T_eec6c_row11_col1, #T_eec6c_row11_col2, #T_eec6c_row12_col1, #T_eec6c_row12_col2 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_eec6c_row13_col1, #T_eec6c_row13_col2 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_eec6c_row14_col1, #T_eec6c_row14_col2, #T_eec6c_row15_col1, #T_eec6c_row15_col2, #T_eec6c_row16_col1, #T_eec6c_row16_col2, #T_eec6c_row17_col1, #T_eec6c_row17_col2, #T_eec6c_row18_col1, #T_eec6c_row18_col2 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_eec6c_row19_col1, #T_eec6c_row19_col2 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_eec6c_row20_col1, #T_eec6c_row20_col2 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_eec6c_row21_col1, #T_eec6c_row21_col2 {
#   background-color: #20938c;
#   color: #f1f1f1;
# }
# #T_eec6c_row22_col1, #T_eec6c_row22_col2 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_eec6c_row23_col1, #T_eec6c_row23_col2 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_eec6c_row24_col1, #T_eec6c_row24_col2 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_eec6c_row25_col1, #T_eec6c_row25_col2 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_eec6c_row26_col1, #T_eec6c_row26_col2 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_eec6c_row27_col1, #T_eec6c_row27_col2, #T_eec6c_row28_col1, #T_eec6c_row28_col2 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_eec6c_row29_col1, #T_eec6c_row29_col2 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# #T_eec6c_row30_col1, #T_eec6c_row30_col2 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_eec6c_row31_col1, #T_eec6c_row31_col2 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_eec6c_row32_col1, #T_eec6c_row32_col2 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_eec6c_row33_col1, #T_eec6c_row33_col2, #T_eec6c_row34_col1, #T_eec6c_row34_col2, #T_eec6c_row35_col1, #T_eec6c_row35_col2, #T_eec6c_row36_col1, #T_eec6c_row36_col2, #T_eec6c_row37_col1, #T_eec6c_row37_col2, #T_eec6c_row38_col1, #T_eec6c_row38_col2, #T_eec6c_row39_col1, #T_eec6c_row39_col2 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_eec6c_row40_col1, #T_eec6c_row40_col2 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_eec6c_row41_col1, #T_eec6c_row41_col2, #T_eec6c_row42_col1, #T_eec6c_row42_col2 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_eec6c_row43_col1, #T_eec6c_row43_col2 {
#   background-color: #2a768e;
#   color: #f1f1f1;
# }
# #T_eec6c_row44_col1, #T_eec6c_row44_col2 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# #T_eec6c_row45_col1, #T_eec6c_row45_col2, #T_eec6c_row46_col1, #T_eec6c_row46_col2, #T_eec6c_row47_col1, #T_eec6c_row47_col2 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_eec6c_row48_col1, #T_eec6c_row48_col2, #T_eec6c_row49_col1, #T_eec6c_row49_col2, #T_eec6c_row50_col1, #T_eec6c_row50_col2, #T_eec6c_row51_col1, #T_eec6c_row51_col2, #T_eec6c_row52_col1, #T_eec6c_row52_col2, #T_eec6c_row53_col1, #T_eec6c_row53_col2, #T_eec6c_row54_col1, #T_eec6c_row54_col2, #T_eec6c_row55_col1, #T_eec6c_row55_col2, #T_eec6c_row56_col1, #T_eec6c_row56_col2, #T_eec6c_row57_col1, #T_eec6c_row57_col2, #T_eec6c_row58_col1, #T_eec6c_row58_col2 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_eec6c_row59_col1, #T_eec6c_row59_col2, #T_eec6c_row60_col1, #T_eec6c_row60_col2, #T_eec6c_row61_col1, #T_eec6c_row61_col2, #T_eec6c_row62_col1, #T_eec6c_row62_col2 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_eec6c_row63_col1, #T_eec6c_row63_col2, #T_eec6c_row64_col1, #T_eec6c_row64_col2, #T_eec6c_row65_col1, #T_eec6c_row65_col2, #T_eec6c_row66_col1, #T_eec6c_row66_col2 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
# }
# #T_eec6c_row67_col1, #T_eec6c_row67_col2 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
# }
# #T_eec6c_row68_col1, #T_eec6c_row68_col2, #T_eec6c_row69_col1, #T_eec6c_row69_col2, #T_eec6c_row70_col1, #T_eec6c_row70_col2, #T_eec6c_row71_col1, #T_eec6c_row71_col2, #T_eec6c_row72_col1, #T_eec6c_row72_col2, #T_eec6c_row73_col1, #T_eec6c_row73_col2, #T_eec6c_row74_col1, #T_eec6c_row74_col2, #T_eec6c_row75_col1, #T_eec6c_row75_col2, #T_eec6c_row76_col1, #T_eec6c_row76_col2, #T_eec6c_row77_col1, #T_eec6c_row77_col2 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_eec6c_row78_col1, #T_eec6c_row78_col2, #T_eec6c_row79_col1, #T_eec6c_row79_col2 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_eec6c_row80_col1, #T_eec6c_row80_col2, #T_eec6c_row81_col1, #T_eec6c_row81_col2 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_eec6c_row82_col1, #T_eec6c_row82_col2, #T_eec6c_row83_col1, #T_eec6c_row83_col2 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_eec6c_row84_col1, #T_eec6c_row84_col2, #T_eec6c_row85_col1, #T_eec6c_row85_col2, #T_eec6c_row86_col1, #T_eec6c_row86_col2 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_eec6c_row87_col1, #T_eec6c_row87_col2, #T_eec6c_row88_col1, #T_eec6c_row88_col2, #T_eec6c_row89_col1, #T_eec6c_row89_col2 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_eec6c_row90_col1, #T_eec6c_row90_col2 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_eec6c_row91_col1, #T_eec6c_row91_col2 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_eec6c_row92_col1, #T_eec6c_row92_col2 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_eec6c_row93_col1, #T_eec6c_row93_col2, #T_eec6c_row94_col1, #T_eec6c_row94_col2, #T_eec6c_row95_col1, #T_eec6c_row95_col2, #T_eec6c_row96_col1, #T_eec6c_row96_col2, #T_eec6c_row97_col1, #T_eec6c_row97_col2 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# #T_eec6c_row98_col1, #T_eec6c_row98_col2 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_eec6c_row99_col1, #T_eec6c_row99_col2 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_eec6c_row100_col1, #T_eec6c_row100_col2 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_eec6c_row101_col1, #T_eec6c_row101_col2, #T_eec6c_row102_col1, #T_eec6c_row102_col2, #T_eec6c_row103_col1, #T_eec6c_row103_col2 {
#   background-color: #39558c;
#   color: #f1f1f1;
# }
# #T_eec6c_row104_col1, #T_eec6c_row104_col2, #T_eec6c_row105_col1, #T_eec6c_row105_col2 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_eec6c_row106_col1, #T_eec6c_row106_col2 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_eec6c_row107_col1, #T_eec6c_row107_col2, #T_eec6c_row108_col1, #T_eec6c_row108_col2 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_eec6c_row109_col1, #T_eec6c_row109_col2, #T_eec6c_row110_col1, #T_eec6c_row110_col2, #T_eec6c_row111_col1, #T_eec6c_row111_col2, #T_eec6c_row112_col1, #T_eec6c_row112_col2 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_eec6c_row113_col1, #T_eec6c_row113_col2, #T_eec6c_row114_col1, #T_eec6c_row114_col2 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_eec6c_row115_col1, #T_eec6c_row115_col2 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_eec6c_row116_col1, #T_eec6c_row116_col2 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_eec6c_row117_col1, #T_eec6c_row117_col2, #T_eec6c_row118_col1, #T_eec6c_row118_col2 {
#   background-color: #3f4889;
#   color: #f1f1f1;
# }
# #T_eec6c_row119_col1, #T_eec6c_row119_col2 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_eec6c_row120_col1, #T_eec6c_row120_col2 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_eec6c_row121_col1, #T_eec6c_row121_col2 {
#   background-color: #481467

# %%
# Setting the path to the shapefile
SHAPEFILE = '/home/jovyan/demo/Countries/ne_10m_admin_0_countries.shp'

# Read shapefile using Geopandas
geo_df = gpd.read_file(SHAPEFILE)[['ADMIN', 'ADM0_A3', 'geometry']]

# Rename columns.
geo_df.columns = ['country', 'country_code', 'geometry']
geo_df.head()


# Drop row for 'Antarctica'. It takes a lot of space in the map and is not of much use
geo_df = geo_df.drop(geo_df.loc[geo_df['country'] == 'Antarctica'].index)

# Next, we need to ensure that our data matches with the country codes. 
iso3_codes = geo_df['country'].to_list()

# Convert to iso3_codes
iso2_codes_list = coco.convert(names=iso3_codes, to='ISO2', not_found='NULL')

# Add the list with iso2 codes to the dataframe
geo_df['iso2_code'] = iso2_codes_list

# There are some countries for which the converter could not find a country code. 
# We will drop these countries.
geo_df = geo_df.drop(geo_df.loc[geo_df['iso2_code'] == 'NULL'].index)

geo_df = geo_df.rename(columns={'country': 'Country'})
# Out:
# Dhekelia Sovereign Base Area not found in regex
# US Naval Base Guantanamo Bay not found in regex
# Siachen Glacier not found in regex
# Baykonur Cosmodrome not found in regex
# Akrotiri Sovereign Base Area not found in regex
# Southern Patagonian Ice Field not found in regex
# Bir Tawil not found in regex
# Indian Ocean Territories not found in regex
# Coral Sea Islands not found in regex
# Spratly Islands not found in regex
# Clipperton Island not found in regex
# Ashmore and Cartier Islands not found in regex
# Bajo Nuevo Bank (Petrel Is.) not found in regex
# Serranilla Bank not found in regex
# Scarborough Reef not found in regex

# %%
#nw DF for Respondent and  Country
country_df = survey_df.loc[:,['Respondent','Country']]
#handling Nulls
country_df = country_df.dropna()
#group by respondent per country
country_Groupby = country_df.groupby(by=["Country"]).count()

top_10_countries = country_Groupby.sort_values(['Respondent','Country'], ascending=False).head(10)


top_10_countries = top_10_countries.reset_index()  # Country & b are now back out of the index, as a normal columns.
top_10_countries.rename(columns={"index": "Country"})
top_10_countries = top_10_countries.loc[:,['Respondent','Country']]
top_10_countries['Country'] = top_10_countries['Country'].str.replace("United States","United States of America")  # Normal indexing works.
top_10_countries['Country'] = top_10_countries['Country'].str.replace("Russian Federation","Russia")  # Normal indexing works.



#top_10_countries.sort_values(['Respondent','Country'], ascending=False).head(10).plot.bar()

merged_df = pd.merge(geo_df, top_10_countries, on= "Country")
merged_df.head(10)
# Out:
#                     Country country_code  \
# 0                     India          IND
# 1                    France          FRA
# 2                    Brazil          BRA
# 3                    Russia          RUS
# 4                   Germany          DEU
# 5                    Poland          POL
# 6            United Kingdom          GBR
# 7  United States of America          USA
# 8                    Canada          CAN
# 9                 Australia          AUS
#
#                                             geometry iso2_code  Respondent
# 0  MULTIPOLYGON (((77.80035 35.49541, 77.81533 35...        IN       13721
# 1  MULTIPOLYGON (((-54.11153 2.11427, -54.13491 2...        FR        2572
# 2  MULTIPOLYGON (((-57.60279 -30.19052, -57.61170...        BR        2505
# 3  MULTIPOLYGON (((87.81632 49.16584, 87.71638 49...        RU        2869
# 4  MULTIPOLYGON (((13.81572 48.76643, 13.78586 48...        DE        6459
# 5  POLYGON ((18.83320 49.51026, 18.83743 49.52695...        PL        2122
# 6  MULTIPOLYGON (((-7.24710 55.06932, -7.25674 55...        GB        6221
# 7  MULTIPOLYGON (((-95.16057 49.36949, -95.10282 ...        US       20309
# 8  MULTIPOLYGON (((-99.79271 67.80492, -99.79528 ...        CA        3393
# 9  MULTIPOLYGON (((131.53590 -31.60556, 131.34555...        AU        2018

# %%
# Print the map
# Set the range for the choropleth
title = 'Number Of Respondents Per Country'
col = 'Respondent'
source = ''
vmin = merged_df[col].min()
vmax = merged_df[col].max()
cmap = 'viridis'

# Create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(20, 8))

# Remove the axis
ax.axis('off')
merged_df.plot(column=col, ax=ax, edgecolor='0.8', linewidth=1, cmap=cmap)


# Add a title
ax.set_title(title, fontdict={'fontsize': '25', 'fontweight': '3'})

# Create an annotation for the data source
ax.annotate(source, xy=(0.1, .08), xycoords='figure fraction', horizontalalignment='left', 
            verticalalignment='bottom', fontsize=10)
            
# Create colorbar as a legend
sm = plt.cm.ScalarMappable(norm=plt.Normalize(vmin=vmin, vmax=vmax), cmap=cmap)

# Empty array for the data range
sm._A = []

# Add the colorbar to the figure
cbaxes = fig.add_axes([0.15, 0.25, 0.01, 0.4])
cbar = fig.colorbar(sm, cax=cbaxes)

# %%
#What is the most suited counrty for each development type?

# %%
NW_df = survey_df.loc[:,['Respondent','Country','Salary','DevType','Gender']]

NW_df = NW_df.dropna()

NW_df_Groupby = NW_df.groupby(by=["Country"]).count()

Top_10_countries_NW_df = NW_df_Groupby.sort_values(['Respondent','Country'], ascending=False).head(10)
# Out:
#                     Respondent  Salary  DevType  Gender
# Country
# United States            12323   12323    12323   12323
# India                     3792    3792     3792    3792
# United Kingdom            3623    3623     3623    3623
# Germany                   3272    3272     3272    3272
# Canada                    1908    1908     1908    1908
# France                    1370    1370     1370    1370
# Brazil                    1269    1269     1269    1269
# Russian Federation        1243    1243     1243    1243
# Australia                 1116    1116     1116    1116
# Poland                    1029    1029     1029    1029

# %%
NW_df["Salary"] = pd.to_numeric(NW_df['Salary'],errors='coerce')
#NW_df["Salary"]=NW_df["Salary"].str.replace(',','')

Top_10_countries_NW_df = Top_10_countries_NW_df.reset_index()  # Country & b are now back out of the index, as a normal columns.
Top_10_countries_NW_df.rename(columns={"index": "Respondent"})
Top_10_countries_NW_df = Top_10_countries_NW_df.loc[:,['Respondent','Country']]

avg_salary = NW_df.groupby(by=["Country","DevType"])['Salary'].mean()

avg_salary = avg_salary.reset_index()  # Country & b are now back out of the index, as a normal columns.
avg_salary.rename(columns={"index": "Salary"})


avg_merged_df = pd.merge(avg_salary, Top_10_countries_NW_df, on= "Country")

avg_merged_df = avg_merged_df.sort_values(['Country','Salary'], ascending=False).head(10)

avg_merged_df.head(10)
# Out:
#             Country                                            DevType  \
# 7843  United States  Database administrator;Designer;Front-end deve...
# 6710  United States  Back-end developer;Database administrator;Desi...
# 6565  United States  Back-end developer;Data scientist or machine l...
# 6536  United States  Back-end developer;Data scientist or machine l...
# 5948  United States  Back-end developer;C-suite executive (CEO, CTO...
# 6037  United States  Back-end developer;C-suite executive (CEO, CTO...
# 7362  United States  Back-end developer;Educator or academic resear...
# 7386  United States  Back-end developer;Embedded applications or de...
# 8192  United States  Embedded applications or devices developer;Ful...
# 5983  United States  Back-end developer;C-suite executive (CEO, CTO...
#
#             Salary  Respondent
# 7843  5.000000e+16       12323
# 6710  9.500000e+07       12323
# 6565  1.800000e+06       12323
# 6536  1.000000e+06       12323
# 5948  6.000000e+05       12323
# 6037  6.000000e+05       12323
# 7362  5.900000e+05       12323
# 7386  5.000000e+05       12323
# 8192  5.000000e+05       12323
# 5983  4.500000e+05       12323
